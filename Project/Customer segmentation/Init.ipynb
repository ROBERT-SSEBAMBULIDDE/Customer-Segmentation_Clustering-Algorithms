# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: google-cloud-bigquery in /shared-libs/python3.11/py/lib/python3.11/site-packages (from -r ./requirements.txt (line 1)) (3.12.0)
# Requirement already satisfied: pip in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 2)) (23.1.2)
# Collecting db-dtypes (from -r ./requirements.txt (line 3))
#   Downloading db_dtypes-1.1.1-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: pandas in /shared-libs/python3.11/py/lib/python3.11/site-packages (from -r ./requirements.txt (line 4)) (1.2.5)
# Requirement already satisfied: numpy in /shared-libs/python3.11/py/lib/python3.11/site-packages (from -r ./requirements.txt (line 5)) (1.26.1)
# Requirement already satisfied: scikit-learn in /shared-libs/python3.11/py/lib/python3.11/site-packages (from -r ./requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: plotly in /shared-libs/python3.11/py/lib/python3.11/site-packages (from -r ./requirements.txt (line 7)) (5.17.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.47.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-cloud-bigquery->-r ./requirements.txt (line 1)) (1.59.0)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-cloud-bigquery->-r ./requirements.txt (line 1)) (2.12.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.15.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-cloud-bigquery->-r ./requirements.txt (line 1)) (1.22.3)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-cloud-bigquery->-r ./requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-cloud-bigquery->-r ./requirements.txt (line 1)) (2.6.0)
# Requirement already satisfied: packaging>=20.0.0 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from google-cloud-bigquery->-r ./requirements.txt (line 1)) (23.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-cloud-bigquery->-r ./requirements.txt (line 1)) (4.24.4)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from google-cloud-bigquery->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.21.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-cloud-bigquery->-r ./requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: pyarrow>=3.0.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from db-dtypes->-r ./requirements.txt (line 3)) (13.0.0)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from pandas->-r ./requirements.txt (line 4)) (2023.3.post1)
# Requirement already satisfied: scipy>=1.5.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from scikit-learn->-r ./requirements.txt (line 6)) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from scikit-learn->-r ./requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from scikit-learn->-r ./requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from plotly->-r ./requirements.txt (line 7)) (8.2.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery->-r ./requirements.txt (line 1)) (1.61.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery->-r ./requirements.txt (line 1)) (2.23.3)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery->-r ./requirements.txt (line 1)) (1.59.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery->-r ./requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery->-r ./requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery->-r ./requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery->-r ./requirements.txt (line 1)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery->-r ./requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery->-r ./requirements.txt (line 1)) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery->-r ./requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery->-r ./requirements.txt (line 1)) (4.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery->-r ./requirements.txt (line 1)) (0.5.0)
# Installing collected packages: db-dtypes
# Successfully installed db-dtypes-1.1.1
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cc7b82d2-507f-4fc5-a569-84ed6f2fa5e5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
